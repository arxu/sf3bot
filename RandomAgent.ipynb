# %%
import sys
sys.path.append("/home/Documents/GitHub/sf3bot")
import random
from MAMEToolkit.sf_environment import Environment

roms_path = "./roms/"
env = Environment("env1", roms_path)
env.start()
while True:
    move_action = random.randint(0, 8)
    attack_action = random.randint(0, 9)
    frames, reward, round_done, stage_done, game_done = env.step(move_action, attack_action)
    if game_done:
        env.new_game()
    elif stage_done:
        env.next_stage()
    elif round_done:
        env.next_round()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_43264/2444376000.py in <module>
#      10     move_action = random.randint(0, 8)
#      11     attack_action = random.randint(0, 9)
# ---> 12     frames, reward, round_done, stage_done, game_done = env.step(move_action, attack_action)
#      13     if game_done:
#      14         env.new_game()
#
# ~/anaconda3/lib/python3.9/site-packages/MAMEToolkit/sf_environment/Environment.py in step(self, move_action, attack_action)
#     209                 actions += index_to_move_action(move_action)
#     210                 actions += index_to_attack_action(attack_action)
# --> 211                 data = self.gather_frames(actions)
#     212                 data = self.check_done(data)
#     213                 return data["frame"], data["rewards"], self.round_done, self.stage_done, self.game_done
#
# ~/anaconda3/lib/python3.9/site-packages/MAMEToolkit/sf_environment/Environment.py in gather_frames(self, actions)
#     180         frames = [data["frame"]]
#     181         for i in range(self.frames_per_step - 1):
# --> 182             data = add_rewards(data, self.sub_step(actions))
#     183             frames.append(data["frame"])
#     184         data["frame"] = frames[0] if self.frames_per_step == 1 else frames
#
# ~/anaconda3/lib/python3.9/site-packages/MAMEToolkit/sf_environment/Environment.py in sub_step(self, actions)
#     188     # Takes the data returned from the step and updates book keeping variables
#     189     def sub_step(self, actions):
# --> 190         data = self.emu.step([action.value for action in actions])
#     191
#     192         p1_diff = (self.expected_health["P1"] - data["healthP1"])
#
# ~/anaconda3/lib/python3.9/site-packages/MAMEToolkit/emulator/Emulator.py in step(self, actions)
#     159         action_string = actions_to_string(actions)
#     160         self.actionPipe.writeln(action_string)  # sends the actions for the game to perform before the next step
# --> 161         data = self.dataPipe.read_data(timeout=10)  # gathers the frame data and memory address values
#     162         return data
#     163
#
# ~/anaconda3/lib/python3.9/site-packages/MAMEToolkit/emulator/pipes/DataPipe.py in read_data(self, timeout)
#      25     def read_data(self, timeout=10):
#      26         data = {}
# ---> 27         line = self.pipe.readln(timeout=timeout)
#      28         cursor = 0
#      29         for k in self.addresses.keys():
#
# ~/anaconda3/lib/python3.9/site-packages/MAMEToolkit/emulator/pipes/Pipe.py in readln(self, timeout)
#      94         if self.mode == 'r':
#      95             try:
# ---> 96                 return self.read_queue.get(timeout=timeout)
#      97             except Exception as e:
#      98                 error = "Failed to read value from '"+self.pipeId+"'"
#
# ~/anaconda3/lib/python3.9/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# ~/anaconda3/lib/python3.9/threading.py in wait(self, timeout)
#     314             else:
#     315                 if timeout > 0:
# --> 316                     gotit = waiter.acquire(True, timeout)
#     317                 else:
#     318                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
